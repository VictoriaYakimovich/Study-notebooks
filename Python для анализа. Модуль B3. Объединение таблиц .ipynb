# %%
import pandas as pd
ratings=pd.read_csv('C:/Users/Vika/Notebooks Python/ratings.csv')
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %% [markdown]
# ratings.csv
# userId — идентификатор пользователя, который поставил фильму оценку
# movieId — идентификатор фильма
# rating — выставленная оценка
# timestamp — время (в формате unix time), когда была выставлена оценка

# %%
movies=pd.read_csv('C:/Users/Vika/Notebooks Python/movies.csv')
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %% [markdown]
# movies.csv
# movieId — идентификатор фильма
# title — название фильма
# genres — список жанров, к которым относится фильм

# %% [markdown]
# Задание 1
# Скачайте файлы ratings.csv и movies.csv из предыдущего шага. Давайте повторим основные методы получения информации о датасете, которые мы изучали в модуле 1 "Общее знакомство с библиотекой Pandas".
#
# Какоe количество строк в файле рейтингов? (Подсказка: количество непустых значений соответствует количеству строк)

# %%
display(ratings.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 4 columns):
# userId       100836 non-null int64
# movieId      100836 non-null int64
# rating       100836 non-null float64
# timestamp    100836 non-null int64
# dtypes: float64(1), int64(3)
# memory usage: 3.1 MB
# None

# %% [markdown]
# Задание 2
# Какое количество жанров имеют фильмы в датасете movies?

# %%
movies.describe(include=['object'])
# Out:
#                            title genres
# count                       9742   9742
# unique                      9737    951
# top     War of the Worlds (2005)  Drama
# freq                           2   1053

# %%
display(movies.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9742 entries, 0 to 9741
# Data columns (total 3 columns):
# movieId    9742 non-null int64
# title      9742 non-null object
# genres     9742 non-null object
# dtypes: int64(1), object(2)
# memory usage: 228.4+ KB
# None

# %% [markdown]
# Задание 4
# Какой минимальный рейтинг можно выставить фильму в датасете модуля?

# %%
ratings.rating.min()
# Out:
# 0.5

# %% [markdown]
# Задание 5
# Какой максимальный рейтинг можно выставить фильму в датасете модуля?

# %%
ratings.rating.max()
# Out:
# 5.0

# %%
joined = ratings.merge(movies, on='movieId', how='left')  #метод merge
joined.head()
# Out:
#    userId  movieId  rating  timestamp                        title  \
# 0       1        1     4.0  964982703             Toy Story (1995)
# 1       1        3     4.0  964981247      Grumpier Old Men (1995)
# 2       1        6     4.0  964982224                  Heat (1995)
# 3       1       47     5.0  964983815  Seven (a.k.a. Se7en) (1995)
# 4       1       50     5.0  964982931   Usual Suspects, The (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                               Comedy|Romance
# 2                        Action|Crime|Thriller
# 3                             Mystery|Thriller
# 4                       Crime|Mystery|Thriller

# %%
len(ratings) == len(joined)
# Out:
# True

# %%
import pandas as pd
ratings = pd.read_csv('ratings_example.txt', sep = '\t')
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144

# %%
movies = pd.read_csv('movies_example.txt', sep = '\t')
movies.head()
# Out:
#    movieId                                      title                   genres
# 0       31                    Dangerous Minds (1995)                     Drama
# 1       32  Twelve Monkeys (a.k.a. 12 Monkeys) (1995)  Mystery|Sci-Fi|Thriller
# 2       31                    Dangerous Minds (1995)                     Drama

# %%
ratings.merge(movies, on = 'movieId', how = 'left')
# Out:
#    userId  movieId  rating   timestamp                    title genres
# 0       1       31     2.5  1260759144  Dangerous Minds (1995)   Drama
# 1       1       31     2.5  1260759144  Dangerous Minds (1995)   Drama

# %%
ratings.merge(movies, on = 'movieId', how = 'right')
# Out:
#    userId  movieId  rating     timestamp  \
# 0     1.0       31     2.5  1.260759e+09
# 1     1.0       31     2.5  1.260759e+09
# 2     NaN       32     NaN           NaN
#
#                                        title                   genres
# 0                    Dangerous Minds (1995)                     Drama
# 1                    Dangerous Minds (1995)                     Drama
# 2  Twelve Monkeys (a.k.a. 12 Monkeys) (1995)  Mystery|Sci-Fi|Thriller

# %%
ratings.merge(movies, on = 'movieId', how = 'inner')
# Out:
#    userId  movieId  rating   timestamp                    title genres
# 0       1       31     2.5  1260759144  Dangerous Minds (1995)   Drama
# 1       1       31     2.5  1260759144  Dangerous Minds (1995)   Drama

# %%
ratings.merge(movies, on = 'movieId', how = 'outer')
# Out:
#    userId  movieId  rating     timestamp  \
# 0     1.0       31     2.5  1.260759e+09
# 1     1.0       31     2.5  1.260759e+09
# 2     NaN       32     NaN           NaN
#
#                                        title                   genres
# 0                    Dangerous Minds (1995)                     Drama
# 1                    Dangerous Minds (1995)                     Drama
# 2  Twelve Monkeys (a.k.a. 12 Monkeys) (1995)  Mystery|Sci-Fi|Thriller

# %%
movies.drop_duplicates(subset = 'movieId', keep = 'first', inplace = True)
movies.head()
# Out:
#    movieId                                      title                   genres
# 0       31                    Dangerous Minds (1995)                     Drama
# 1       32  Twelve Monkeys (a.k.a. 12 Monkeys) (1995)  Mystery|Sci-Fi|Thriller

# %%
ratings.merge(movies, how = 'left', on = 'movieId')
# Out:
#    userId  movieId  rating   timestamp                    title genres
# 0       1       31     2.5  1260759144  Dangerous Minds (1995)   Drama

# %% [markdown]
# Задания

# %%
#информация о наличии товара на складе
items_dict = {

    'item_id': [417283, 849734, 132223, 573943, 19475, 3294095, 382043, 302948, 100132, 312394], 

    'vendor': ['Samsung', 'LG', 'Apple', 'Apple', 'LG', 'Apple', 'Samsung', 'Samsung', 'LG', 'ZTE'],

    'stock_count': [54, 33, 122, 18, 102, 43, 77, 143, 60, 19]

}

# %%
#данные о покупках товаров
purchase_log = {

    'purchase_id': [101, 101, 101, 112, 121, 145, 145, 145, 145, 221],

    'item_id': [417283, 849734, 132223, 573943, 19475, 3294095, 382043, 302948, 103845, 100132], 

    'price': [13900, 5330, 38200, 49990, 9890, 33000, 67500, 34500, 89900, 11400]

}

# %% [markdown]
# item_id — идентификатор модели (по этому столбцу будем объединять датафреймы)
# vendor — производитель модели
# stock_count — какое количество данных моделей есть на складе (в штуках)
# purchase_id — идентификатор покупки
# price — стоимость модели в покупке

# %%
items_df = pd.DataFrame(items_dict)     #переведем эти словари в датафреймы для удобства 
purchase_df = pd.DataFrame(purchase_log)
display(items_df)
display(purchase_df)
# Out:
#    item_id   vendor  stock_count
# 0   417283  Samsung           54
# 1   849734       LG           33
# 2   132223    Apple          122
# 3   573943    Apple           18
# 4    19475       LG          102
# 5  3294095    Apple           43
# 6   382043  Samsung           77
# 7   302948  Samsung          143
# 8   100132       LG           60
# 9   312394      ZTE           19
#    purchase_id  item_id  price
# 0          101   417283  13900
# 1          101   849734   5330
# 2          101   132223  38200
# 3          112   573943  49990
# 4          121    19475   9890
# 5          145  3294095  33000
# 6          145   382043  67500
# 7          145   302948  34500
# 8          145   103845  89900
# 9          221   100132  11400

# %% [markdown]
# Задание 1
# Объедините получившиеся датафреймы по столбцу item_id с типом outer.
# Модель с каким item_id есть в статистике продаж purchase_df, но не учтена на складе? (Подсказка: подумайте, какой датафрейм должен быть "левым", а какой "правым", чтобы получить необходимые данные.) Введите ответ в виде целого числа

# %%
items_df.merge(purchase_df, on = 'item_id', how = 'outer')
# Out:
#     item_id   vendor  stock_count  purchase_id    price
# 0    417283  Samsung         54.0        101.0  13900.0
# 1    849734       LG         33.0        101.0   5330.0
# 2    132223    Apple        122.0        101.0  38200.0
# 3    573943    Apple         18.0        112.0  49990.0
# 4     19475       LG        102.0        121.0   9890.0
# 5   3294095    Apple         43.0        145.0  33000.0
# 6    382043  Samsung         77.0        145.0  67500.0
# 7    302948  Samsung        143.0        145.0  34500.0
# 8    100132       LG         60.0        221.0  11400.0
# 9    312394      ZTE         19.0          NaN      NaN
# 10   103845      NaN          NaN        145.0  89900.0

# %% [markdown]
# Задание 3
# Сформируйте датафрейм merged, в котором в результате объединения purchase_df и items_df останутся модели, которые учтены на складе и имели продажи. Сколько всего таких моделей?

# %%
merged=items_df.merge(purchase_df, on = 'item_id', how = 'inner')
display(merged)
# Out:
#    item_id   vendor  stock_count  purchase_id  price
# 0   417283  Samsung           54          101  13900
# 1   849734       LG           33          101   5330
# 2   132223    Apple          122          101  38200
# 3   573943    Apple           18          112  49990
# 4    19475       LG          102          121   9890
# 5  3294095    Apple           43          145  33000
# 6   382043  Samsung           77          145  67500
# 7   302948  Samsung          143          145  34500
# 8   100132       LG           60          221  11400

# %% [markdown]
# Задание 4
# Посчитайте объем выручки для каждой модели, которую можно получить, распродав все остатки на складе. Модель с каким item_id имеет максимальное значение выручки после распродажи остатков? Ответ дайте в виде целого числа
# Примечание: перемножение столбцов датафрейма можно производить разными способами, но самый простой - перемножение "в лоб" вида df['col1'] = df['col2'] * df['col3']. Для присоединения новых данных к датафрейму тоже можно использовать различные методы, включая функцию .append(), которая позволяет присоединять к датафрейму другой датафрейм, серии или словари.

# %%
merged['summa']=merged['stock_count'] * merged['price']   
display(merged)
# Out:
#    item_id   vendor  stock_count  purchase_id  price    summa
# 0   750600  Samsung           54          101  13900   750600
# 1   175890       LG           33          101   5330   175890
# 2  4660400    Apple          122          101  38200  4660400
# 3   899820    Apple           18          112  49990   899820
# 4  1008780       LG          102          121   9890  1008780
# 5  1419000    Apple           43          145  33000  1419000
# 6  5197500  Samsung           77          145  67500  5197500
# 7  4933500  Samsung          143          145  34500  4933500
# 8   684000       LG           60          221  11400   684000

# %%
merged['summa'].max()
# Out:
# 5197500

# %%
merged[merged['summa'] == merged['summa'].max()]
# Out:
#    item_id   vendor  stock_count  purchase_id  price    summa
# 6  5197500  Samsung           77          145  67500  5197500

# %%
merged['summa'].describe()
# Out:
# count    9.000000e+00
# mean     2.192166e+06
# std      2.083432e+06
# min      1.758900e+05
# 25%      7.506000e+05
# 50%      1.008780e+06
# 75%      4.660400e+06
# max      5.197500e+06
# Name: summa, dtype: float64

# %% [markdown]
# Задание 5
# Посчитайте итоговую выручку из прошлого задания по всем моделям. Ответ дайте в виде целого числа.

# %%
merged['summa'].sum()
# Out:
# 19729490

# %% [markdown]
# Библиотека os

# %%
import os

# %%
files = os.listdir('data')
files
# Out:
# ['ratings_1.txt',
#  'ratings_10.txt',
#  'ratings_2.txt',
#  'ratings_3.txt',
#  'ratings_4.txt',
#  'ratings_5.txt',
#  'ratings_6.txt',
#  'ratings_7.txt',
#  'ratings_8.txt',
#  'ratings_9.txt']

# %% [markdown]
# Задание:
# После чтения папки список файлов оказался следующим:
# files = ['setup.py', 'ratings.txt', 'stock_stats.txt', 'movies.txt', 'run.sh', 'game_of_thrones.mov']
# Создайте на основе списка files новый список data, в который поместите только файлы, содержащие в названии "txt".

# %%
files = ['setup.py', 'ratings.txt', 'stock_stats.txt', 'movies.txt', 'run.sh', 'game_of_thrones.mov']
data=[]
for i in range (0, len(files)):
    if 'txt' in files[i]:
        data.append(files[i])
print(data)
# Out:
# ['ratings.txt', 'stock_stats.txt', 'movies.txt']

# %% [markdown]
# Склеивание датафреймов

# %% [markdown]
# Cоздадим пустой датафрейм с нужными названиями столбцов
# data = pd.DataFrame(columns = ['userId', 'movieId', 'rating', 'timestamp'])
#
# Для каждого имени файла filename будем записывать его содержимое в датафрейм temp
# temp = pd.read_csv( os.path.join('data', filename), names = ['userId', 'movieId', 'rating', 'timestamp'] )
#
# И «прибавлять» содержимое очередного файла к data:
# data = pd.concat([data, temp])
#
# Использование временного датафрейма temp аналогично тому как мы прибавляем значение к переменной i в цикле: i = i + 1. Только вместо i у нас датафрейм data, а вместо единицы — temp.

# %% [markdown]
# Задание
# Напишите цикл, который собирает содержимое файлов папки data в единый датафрейм data.
# Сколько строк в датафрейме data?

# %%
files = os.listdir('data')
data = pd.DataFrame(columns = ['userId', 'movieId', 'rating', 'timestamp'])
for filename in files:
    temp = pd.read_csv( os.path.join('data', filename), names = ['userId', 'movieId', 'rating', 'timestamp'] )
    data = pd.concat([data, temp])
data
# Out:
#      userId movieId  rating   timestamp
# 0         1      31     2.5  1260759144
# 1         1    1029     3.0  1260759179
# 2         1    1061     3.0  1260759182
# 3         1    1129     2.0  1260759185
# 4         1    1172     4.0  1260759205
# 5         1    1263     2.0  1260759151
# 6         1    1287     2.0  1260759187
# 7         1    1293     2.0  1260759148
# 8         1    1339     3.5  1260759125
# 9         1    1343     2.0  1260759131
# 10        1    1371     2.5  1260759135
# 11        1    1405     1.0  1260759203
# 12        1    1953     4.0  1260759191
# 13        1    2105     4.0  1260759139
# 14        1    2150     3.0  1260759194
# 15        1    2193     2.0  1260759198
# 16        1    2294     2.0  1260759108
# 17        1    2455     2.5  1260759113
# 18        1    2968     1.0  1260759200
# 19        1    3671     3.0  1260759117
# 20        2      10     4.0   835355493
# 21        2      17     5.0   835355681
# ...

# %% [markdown]
# Задание 3
# Какое количество раз была выставлена низшая оценка 0.5 в наших рейтингах?

# %%
ratings[ratings.rating==0.5].rating.count()
# Out:
# 1370

# %% [markdown]
# Задание 4
# Объедините датафреймы ratings и movies, используя параметр how='outer'.
# Какое количество строк в получившемся датафрейме?

# %%
ratings.merge(movies, on = 'movieId', how = 'outer')
# Out:
#         userId  movieId  rating     timestamp  \
# 0          1.0        1     4.0  9.649827e+08
# 1          5.0        1     4.0  8.474350e+08
# 2          7.0        1     4.5  1.106636e+09
# 3         15.0        1     2.5  1.510578e+09
# 4         17.0        1     4.5  1.305696e+09
# 5         18.0        1     3.5  1.455210e+09
# 6         19.0        1     4.0  9.657056e+08
# 7         21.0        1     3.5  1.407619e+09
# 8         27.0        1     3.0  9.626853e+08
# 9         31.0        1     5.0  8.504666e+08
# 10        32.0        1     3.0  8.567361e+08
# 11        33.0        1     3.0  9.396474e+08
# 12        40.0        1     5.0  8.320590e+08
# 13        43.0        1     5.0  8.489940e+08
# 14        44.0        1     3.0  8.692519e+08
# 15        45.0        1     4.0  9.511702e+08
# 16        46.0        1     5.0  8.347879e+08
# 17        50.0        1     3.0  1.514238e+09
# 18        54.0        1     3.0  8.302473e+08
# ...

# %% [markdown]
# Задание 5
# Найдите в датафрейме movies фильм с movieId=3456.
# Какой у него год выпуска?
# P. S. Попробуйте найти movieId этого фильма в датафрейме ratings. Это будет ключом к ответу на следующее задание

# %%
movies[movies.movieId==3456]
# Out:
#       movieId                                         title genres
# 2587     3456  Color of Paradise, The (Rang-e khoda) (1999)  Drama

# %%
ratings[ratings.movieId==3456]
# Out:
# Empty DataFrame
# Columns: [userId, movieId, rating, timestamp]
# Index: []

# %% [markdown]
# Задание 6
# Сравните количество строк в датафрейме из задания 4 (после объединения датафреймов ratings и movies) с количеством строк в ratings. Почему в данном случае число строк увеличилось?
