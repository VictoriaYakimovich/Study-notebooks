# %% [markdown]
# Перебор элементов списка:

# %%
rainbow_list = 'каждый охотник желает знать где сидит фазан'.split()
for word in rainbow_list:
    print(word)
# Out:
# каждый
# охотник
# желает
# знать
# где
# сидит
# фазан

# %% [markdown]
# Перебор элементов словаря (несколько вариантов):

# %%
rainbow_dict = {'каждый': 'красный', 
                'охотник': 'оранжевый', 
                'желает': 'жёлтый', 
                'знать': 'зелёный', 
                'где': 'голубой', 
                'сидит': 'синий', 
                'фазан': 'фиолетовый'}

# Перебираем ключи
for word in rainbow_dict.keys():
    print(word)

# Перебираем значения
for color in rainbow_dict.values():
    print(color)

# Перебираем пары ключ-значение
for word, color in rainbow_dict.items():
    print(word, color)
# Out:
# каждый
# охотник
# желает
# знать
# где
# сидит
# фазан
# красный
# оранжевый
# жёлтый
# зелёный
# голубой
# синий
# фиолетовый
# каждый красный
# охотник оранжевый
# желает жёлтый
# знать зелёный
# где голубой
# сидит синий
# фазан фиолетовый

# %% [markdown]
# Аналогично можно сделать для строки:

# %%
string = 'Вы - самый крутой студент в SkillFactory'
for letter in string:
    print(letter, end = '')
# Out:
# Вы - самый крутой студент в SkillFactory

# %% [markdown]
# Задание 1.
# Используя срез, напишите код, с помощью которого можно извлечь из строки proverb слово "Программист".
# Код должен быть написан в одну строку без пробелов. Используйте положительные индексы. Оба индекса среза задайте в явном виде.

# %%
proverb = 'Программисты - это устройства, преобразующие кофеин в код.' 
proverb[0:11]
# Out:
# 'Программист'

# %% [markdown]
# Задание 2.
# Напишите код, с помощью которого можно извлечь из строки proverb слово "кофе".
# Код должен быть написан в одну строку без пробелов. Используйте отрицательные индексы. Оба индекса среза задайте в явном виде.

# %%
proverb = 'Программисты - это устройства, преобразующие кофеин в код.' 
proverb[-13:-9]
# Out:
# 'кофе'

# %% [markdown]
# Задание 3.
# Отметьте варианты кода, в результате выполнения которых значением переменной result будет слово "устройство".

# %%
proverb = 'Программисты - это устройства, преобразующие кофеин в код.' 
proverb[19:29] 
result = proverb[19:28]+'о'     # добавляет символ к имеющимся, без пробела
print(result)
result = proverb[19:28],'о'     # добавляет отдельные элементы str в список, через запятую   - не подходит
print(result)
result = proverb.split()[3][:-2]+'о'  # разбивает строку на список через пробел; затем берет срез из 3-го элемента списка
print(result)
# Out:
# устройство
# ('устройств', 'о')
# устройство

# %% [markdown]
# Задание 4*
# Напишите программу, которая "зашифровывает" текст, хранящийся в переменной proverb, меняя местами символы, стоящие на нечётных и чётных позициях. Результат шифрования нужно вывести на экран с помощью функции print
# Используйте переменную proverb для хранения исходной фразы и переменную new_proverb для хранения "зашифрованной" фразы.
# Пример: после шифровки начало фразы должно выглядеть так: рПгоарммсиыт

# %%
proverb = 'Программисты - это устройства, преобразующие кофеин в код.' 
proverb_even=proverb[0::2]
proverb_odd=proverb[1::2]
new=[]
for i in range(len(proverb_odd)):
    new.append(proverb_odd[i])
    new.append(proverb_even[i])
new_proverb=''.join(new)
print(new_proverb)
# Out:
# рПгоарммсиыт- э оту тсорсйвт,ап ербоарузщюеик фоие н вок.д

# %%
proverb = 'Программисты - это устройства, преобразующие кофеин в код.' 
new=[]
for i in range(29):
    new.append(proverb[1::2][i])
    new.append(proverb[0::2][i])
new_proverb=''.join(new)
print(new_proverb)
# Out:
# рПгоарммсиыт- э оту тсорсйвт,ап ербоарузщюеик фоие н вок.д

# %%
proverb = 'Программисты - это устройства, преобразующие кофеин в код.' 
new_proverb=''
for i in range(0,len(proverb)-1,2):
    new=proverb[i+1]+proverb[i]
    new_proverb=new_proverb+new
print(new_proverb)
# Out:
# рПгоарммсиыт- э оту тсорсйвт,ап ербоарузщюеик фоие н вок.д

# %% [markdown]
# Задание 5.
# Некоторые слова одинаково читаются как слева направо, так и справа налево. Такие слова называются палиндромами.
# Напишите программу, которая оценивает слово, заданное в перееменной basic_word, и выдаёт сообщение: 'Слово "..." является палиндромом' в случае, если заданное слово одинаково читается слева направо и справа налево, и сообщение: 'Слово "..." - это не палиндром' в противном случае.
# Вместо многоточия в каждой из фраз должно стоять слово, заданное в переменной basic_word. Обратите внимание на то, что заданное слово должно быть взято в кавычки.
# При написании кода используйте две обязательные переменные: basic_word для хранения заданного слова и inverted_word - для хранения перевёрнутого варианта заданного слова. Во время проверки кода на платформе используйте значение basic_word = 'программирование'.

# %%
basic_word = input('Введите слово: ').lower()
inverted_word=''
for i in range(1,len(basic_word)+1):
    inverted_word=inverted_word+basic_word[-i]
if inverted_word==basic_word:
    print('Слово "{}" является палиндромом'.format(basic_word))
else:    
    print('Слово "{}" - это не палиндром'.format(basic_word))
# Out:
# Введите слово: gfgfg
# Слово "gfgfg" является палиндромом

# %%
basic_word = input('Введите слово: ').lower()
inverted_word=basic_word[::-1]
if inverted_word==basic_word:
    print('Слово "{}" является палиндромом'.format(basic_word))
else:    
    print('Слово "{}" - это не палиндром'.format(basic_word))
# Out:
# Введите слово: памап
# Слово "памап" является палиндромом

# %% [markdown]
# 3.3 Поиск подстроки в строке

# %%
city_list = ['Москва', 'Санкт-Петербург', 'Новосибирск', 
             'Екатеринбург', 'Нижний Новгород', 'Казань', 
             'Челябинск', 'Омск', 'Самара', 'Ростов-на-Дону']
counter = 0
for city in city_list:
    if ' ' in city or '-' in city:
        counter += 1
print('Число городов со сложными названиями - {}'.format(counter))
# Out:
# Число городов со сложными названиями - 3

# %% [markdown]
# Дана переменная email, содержащая адрес электронной почты Вашего нового знакомого. Нужно извлечь из этой переменной адрес домена, на котором зарегистрирована почта.
# Суть решения  заключается в следующем: поскольку известно, что адрес домена в адресе электронной почты следует сразу после символа "@", нам достаточно узнать номер позиции, которую занимает знак "@" и извлечь из строки все символы, следующие за "@". Давайте рассмотрим код решения этой задачи:

# %%
email = 'VeryBigBoss@skillfactory.ru'
pos = email.find('@')                         # метод find
domain = email[pos+1:]
print(domain)
# Out:
# skillfactory.ru

# %% [markdown]
# Подсчёт количества упоминаний имени "Грека" (в разных падежах) в известной скороговорке:

# %%
tongue_twister = 'Ехал Грека через реку, видит Грека - в реке рак. Сунул Грека руку в реку, рак за руку Греку - цап!'
counter = tongue_twister.count('Грек')        # метод count
print(counter)

# %% [markdown]
# Задание 1
# Что будет храниться в переменной counter после выполнения кода?

# %%
proverbs = ['Без труда не вытянешь и рыбку из пруда', 
            'Терпение и труд всё перетрут', 
            'Работа не волк - в лес не убежит', 
            'Чем труднее дело, тем выше честь', 
            'Учиться, учиться и учиться!']

counter = 0
for proverb in proverbs:
    if 'труд' in proverb:
        counter += 1

# %% [markdown]
# Задание 2
# Что хранится в переменной secret?

# %%
proverb = 'Хорошо написанная программа - это программа, написанная 2 раза'

while True:
    index = proverb.find('программа')
    if index == -1:
        break
    secret = proverb[:index].split()[-1]
    proverb = proverb[index+9:] 
print(secret)
print(proverb)
# Out:
# это
# , написанная 2 раза

# %% [markdown]
# Задание 3
# Дана переменная email, содержащая произвольный адрес электронной почты. Напишите универсальный код, с помощью которого можно извлечь из этого адреса адрес домена.
# Пояснения:
# Код должен быть написан в одну строку без пробелов.
# Не используйте никаких дополнительных имён переменных, кроме переменной email.
# Не присваивайте результат извлечения никакой другой переменной.
# Используйте апострофы (не кавычки!) для обозначения символа, позицию которого нужно найти в строке.

# %%
email = 'VeryBigBoss@skillfactory.ru'
domain = email[email.find('@')+1:]

# %% [markdown]
# Задание 4*
# Дано вещественное число. Напишите программу, которая считает сумму цифр дробной части числа. Результат вычислений нужно вывести на экран с помощью функции print
# Используйте переменную number = 56.257 для хранения заданного числа и не меняйте её в процессе выполнения кода.

# %%
number=56.257
number_str=str(number)
numbers=number_str[number_str.find('.')+1:]
sum_numbers=0
for i in range(len(numbers)):
    sum_numbers=sum_numbers+int(numbers[i])
print(sum_numbers)
# Out:
# 14

# %% [markdown]
# Задание 5**
# Дан список emails_list, содержащий электронные адреса десяти человек. Вам нужно написать программу, которая создаёт словарь emails_dict. Ключами словаря дложны быть адреса доменов, а значениями - количество электронных адресов из списка emails_list, зарегистрированных на каждом домене.

# %%
emails_list = ['vasya@mail.ru', 
          'akakiy@yandex.ru', 
          'spyderman@yandex.ru', 
          'XFiles@gmail.com', 
          'hello@mail.ru', 
          'noname@gmail.com', 
          'DonaldTrump@mail.ru', 
          'a768#af@yandex.ru', 
          'Ivan_Ivanovich@yandex.ru', 
          'thebestmail@yandex.ru']
list_domains=[]
for email in emails_list:
    domain = email[email.find('@')+1:]
    list_domains.append(domain)
import collections
c = collections.Counter()
for domain in list_domains:
    c[domain] += 1  
emails_dict=dict(c)
print(emails_dict)
# Out:
# {'mail.ru': 3, 'yandex.ru': 5, 'gmail.com': 2}

# %% [markdown]
# 3.4 Преобразование строк

# %%
new_numbers = []
for number in '3,14 2,71 6,02 11,22 123,987'.split():
    new_numbers.append(float(number.replace(',', '.')))
print(new_numbers)
# Out:
# [3.14, 2.71, 6.02, 11.22, 123.987]

# %% [markdown]
# Задание 1
# Чему будет равно значение переменной secret после выполнения кода?

# %%
string = 'Интернет-открытки - это лучшее средство для мужчины сказать женщине о своих чувствах прямо в глаза.'
secret = string[24:30]
new_string = string.replace(secret.lower(), secret.upper()) 
secret=secret*3
print(secret)
# Out:
# лучшеелучшеелучшее

# %% [markdown]
# Задание 4
# Дана переменная string, в которой нужно заменить все знаки препинания на смайлики (':)'). Знаками препинания считайте символы: точка, запятая, двоеточие, тире (дефис), восклицательный и вопросительный знаки. Значение переменной string должно измениться в процессе выполнения программы.
# Решите задачу для string = 'Тяжёлая интернет-зависимость - это когда ты выходишь из интернета, а он из тебя нет.'
# Пример:
# исходное значение переменной: string = 'Привет, Андрей!'
# итоговое значение переменной: string = 'Привет:) Андрей:)'

# %%
string = 'Тяжёлая интернет-зависимость - это когда ты выходишь из интернета, а он из тебя нет.' 
string=string.replace(':', ':)')
string=string.replace('.', ':)')
string=string.replace(',', ':)')
string=string.replace('-', ':)')
string=string.replace('!', ':)')
string=string.replace('?', ':)')
print(string)
# Out:
# Тяжёлая интернет:)зависимость :) это когда ты выходишь из интернета:) а он из тебя нет:)

# %% [markdown]
# Задание 5*
# Дана переменная name, в которой хранится имя пользователя, записанное русскими буквами. Напишите программу, которая перебирает имя по буквам и для каждой буквы выводит сообщение: "... - гласная буква" или "... - согласная буква", где вместо многоточия нужно подставить букву из имени пользователя.
# Значение переменной name не должно меняться в ходе выполнения программы. В сообщениях, выводимых на экран, буквы из имени пользователя должны выводиться в том же регистре, в котором они присутствуют в переменной name.
# Решите задачу для name = 'Севастиан'
# Пример работы программы для имени Анна:
# А - гласная буква
# н - согласная буква
# н - согласная буква
# а - гласная буква
# Подсказка: чтобы избавить себя от необходимости выполнять проверку сложного составного условия, Вы можете создать два списка с буквами: в одном хранить гласные буквы, а в другом - согласные.

# %%
name = 'Севастиан'
vowels='а, е, е, и, о, у, ы, э, ю, я'
consonants='б, в, г, д, ж, з, к, л, м, н, п, р, с, т, ф, х, ц, ч, ш, щ'
for i in range(len(name)):
    if name[i].lower() in vowels:
        print(name[i],'- гласная буква')
    elif name[i].lower() in consonants:
        print(name[i],'- согласная буква')
    else:
        print('что-то не то')
# Out:
# С - согласная буква
# е - гласная буква
# в - согласная буква
# а - гласная буква
# с - согласная буква
# т - согласная буква
# и - гласная буква
# а - гласная буква
# н - согласная буква

# %% [markdown]
# 3.6 Модуль re для регулярных выражений

# %%
import re 
pattern = re.compile('[А-Я][а-я]*\W')
string = '!!! Йо! Учиться, учиться и учиться! Вперёд! Только вперёд!' 
pattern.match(string)    # метод match вернул нам None

# %%
pattern.search(string)
# Out:
# <re.Match object; span=(4, 7), match='Йо!'>

# %%
pattern.findall(string)
# Out:
# ['Йо!', 'Учиться,', 'Только ']

# %%
Задание 1 
Укажите индекс, с которого в переменной text начинается подстрока, соответствующая паттерну:
\d+

# %% [markdown]
# text = 'Разработка языка Python была начата в конце 1980-х годов сотрудником голландского института CWI Гвидо ван Россумом. Для распределённой ОС Amoeba требовался расширяемый скриптовый язык, и Гвидо начал писать Python на досуге, позаимствовав некоторые наработки для языка ABC (Гвидо участвовал в разработке этого языка, ориентированного на обучение программированию). В феврале 1991 года Гвидо опубликовал исходный текст в группе новостей alt.sources. Название языка произошло вовсе не от вида пресмыкающихся. Автор назвал язык в честь популярного британского комедийного телешоу 1970-х "Летающий цирк Монти Пайтона".'

# %%
text = 'Разработка языка Python была начата в конце 1980-х годов сотрудником голландского института CWI Гвидо ван Россумом. Для распределённой ОС Amoeba требовался расширяемый скриптовый язык, и Гвидо начал писать Python на досуге, позаимствовав некоторые наработки для языка ABC (Гвидо участвовал в разработке этого языка, ориентированного на обучение программированию). В феврале 1991 года Гвидо опубликовал исходный текст в группе новостей alt.sources. Название языка произошло вовсе не от вида пресмыкающихся. Автор назвал язык в честь популярного британского комедийного телешоу 1970-х "Летающий цирк Монти Пайтона".'
pattern = re.compile('\d+')
pattern.search(text)
#print(pattern.search(text)[0])
# Out:
# <re.Match object; span=(44, 48), match='1980'>

# %% [markdown]
# Задание 2
# Какие элементы переменной text соответствуют данному паттерну:
# [A-Za-z]+

# %%
pattern = re.compile('[A-Za-z]+')
pattern.findall(text)
#print(pattern.findall(text)[2])
# Out:
# ['Python', 'CWI', 'Amoeba', 'Python', 'ABC', 'alt', 'sources']

# %% [markdown]
# Задание 3
# Какие элементы переменной text соответствуют данному паттерну:
# [А-Яа-я]+ка

# %%
pattern = re.compile('[А-Яа-я]+ка')
pattern.findall(text)
# Out:
# ['Разработка', 'языка', 'языка', 'языка', 'языка', 'пресмыка']

# %% [markdown]
# Задание 4
# Используя возможности модуля re определите, сколько слов, содержащих русские буквы "а" и "и", разделённые любыми двумя буквами, содержится в переменной text. Введите количество слов в поле для ответа.

# %%
pattern = re.compile('а[А-Яа-я][А-Яа-я]и')
pattern.findall(text)
# Out:
# ['асши', 'амми', 'ающи', 'ающи']

# %% [markdown]
# Задание 5*
# Используя возможности модуля re определите количество пар слов, в которых первое слово заканчивается на гласную русскую букву, а второе начинается на согласную (также русскую). Введите количество найденных пар слов в поле для ответа.
# Во время подсчёта не учитывайте регистр букв (т.е. при подсчёте должны учитываться как вариант: "...а П..." , так и вариант: "...а п..." ). Предлоги и союзы считайте полноправными словами, даже если они состоят из одной буквы.
# Если между словами имеется знак препинания - считайте, что эти два слова НЕ удовлетворяют критерию поиска (т.е. вариант: "...а, П..." НЕ должен учитываться при подсчёте).

# %%
pattern = re.compile('[аеёиоуыэюяАЕЁИОУЫЭЮЯ]\s[бвгджзклмнпрстфхцчшщБВГДЖЗКЛМНПРСТФХЦЧШЩ]')
pattern.findall(text)
# Out:
# ['а н',
#  'а в',
#  'о в',
#  'я р',
#  'я р',
#  'и Г',
#  'о н',
#  'а д',
#  'е н',
#  'и д',
#  'о н',
#  'е п',
#  'а Г',
#  'е н',
#  'а п',
#  'о в',
#  'е н',
#  'а п',
#  'о б',
#  'о к',
#  'о т',
#  'и П']

# %% [markdown]
# 3.7 Построчное чтение файла

# %%
f = open('StudentsPerformance.xls') 
for line in f:
    print(line)
# Out:
# "gender","race/ethnicity","parental level of education","lunch","test preparation course","math score","reading score","writing score"
#
# "female","group B","bachelor's degree","standard","none","72","72","74"
#
# "female","group C","some college","standard","completed","69","90","88"
#
# "female","group B","master's degree","standard","none","90","95","93"
#
# "male","group A","associate's degree","free/reduced","none","47","57","44"
#
# "male","group C","some college","standard","none","76","78","75"
#
# "female","group B","associate's degree","standard","none","71","83","78"
#
# "female","group B","some college","standard","completed","88","95","92"
#
# "male","group B","some college","free/reduced","none","40","43","39"
#
# "male","group D","high school","free/reduced","completed","64","64","67"
#
# "female","group B","high school","free/reduced","none","38","60","50"
#
# "male","group C","associate's degree","standard","none","58","54","52"
#
# ...

# %% [markdown]
# Считаем девочек и мальчиков:
#
# 1) Создаём две переменные-счётчика для подсчёта количества мальчиков и девочек.
# 2) Организуем цикл с параметром для построчного чтения файла. На каждом шаге цикла параметр будет принимать значение очередной строки.
# 3) Превращаем строку в список с помощью метода split. В качестве разделителя указываем запятую.
# 4) Извлекаем из списка первый элемент и отрезаем от него первый и последний символы (кавычки).
# 5) Смотрим, чему равно значение извлечённого элемента. Если это «female», то увеличиваем на 1 счётчик девочек, если «male» — то счётчик мальчиков.
# 6) После завершения цикла выводим содержимое обоих счётчиков на экран.

# %%
f = open('StudentsPerformance.xls')
males = 0                         # создаём две переменные-счётчика 
females = 0 
for line in f:                    # построчно читаем файл
    info = line.split(',')        # превращаем строку в список
    gender = info[0][1:-1]        # извлекаем из списка первый элемент и отрезаем от него первый и последний символы (кавычки)
    if gender == 'female':
        females += 1
    elif gender == 'male':
        males +=1
print('Мальчиков: {}, девочек: {}'.format(males, females))
# Out:
# Мальчиков: 482, девочек: 518

# %% [markdown]
# Задание 1
# У скольких абитуриентов родители имеют диплом бакалавра (bachelor's degree)?
# Введите ответ в виде целого числа. При написании кода обратите внимание на использование кавычек/апострофов

# %%
f = open('StudentsPerformance.xls')
parents_degree = 0                         
for line in f:                   
    info = line.split(',')     
    degree = info[2][1:-1]       
    if degree == "bachelor's degree":
        parents_degree += 1
print(parents_degree)
# Out:
# 118

# %% [markdown]
# Задание 2
# Сколько разных вариантов значений встречается в столбце "parental level of education"?
# Введите ответ в виде целого числа.
# Подсказка 1: для хранения уникальных вариантов Вы можете использовать список.
# Подсказка 2: не забудьте, что первая строка файла содержит заголовки столбцов и не должна учитываться при обработке

# %%
f = open('StudentsPerformance.xls')
all_parents_degree=[]
for line in f:                   
    info = line.split(',')     
    all_parents_degree.append(info[2][1:-1])
all_parents_degree=all_parents_degree[1:]       # отсекаем первое слово из строки-шапки
import collections
c = collections.Counter()
for degree in all_parents_degree:
    c[degree] += 1  
print(c)
# Out:
# Counter({'some college': 226, "associate's degree": 222, 'high school': 196, 'some high school': 179, "bachelor's degree": 118, "master's degree": 59})

# %% [markdown]
# Задание 3
# Сколько процентов абитуриентов полноценно пообедали перед экзаменом? (У скольких процентов абитуриентов значение столбца "lunch" = "standard").
# Ответ введите в виде десятичной дроби. Знак процента вводить не нужно.

# %%
f = open('StudentsPerformance.xls')
i=-1 
j=0
for line in f:   
    i=i+1
    info = line.split(',')     
    lunch = info[3][1:-1]       
    if lunch == "standard":
        j += 1
print(j)
print(i)
procent=j/i*100
print(procent)
# Out:
# 645
# 1000
# 64.5

# %% [markdown]
# Задание 4
# Сколько абитуриентов относится к этнической группе "group C"?
# Введите ответ в виде целого числа.

# %%
f = open('StudentsPerformance.xls')
j=0
for line in f:   
    info = line.split(',')     
    lunch = info[1][1:-1]       
    if lunch == "group C":
        j += 1
print(j)
# Out:
# 319

# %% [markdown]
# Задание 5
# Сколько разных этнических групп встречается в файле?
# Введите ответ в виде целого числа.
# Подсказка 1: для хранения уникальных вариантов Вы можете использовать список.
# Подсказка 2: не забудьте, что первая строка файла содержит заголовки столбцов и не должна учитываться при обработке

# %%
f = open('StudentsPerformance.xls')
groups=[]
for line in f:                   
    info = line.split(',')     
    groups.append(info[1][1:-1])
groups=groups[1:]       # отсекаем первое слово из строки-шапки
import collections
c = collections.Counter()
for group in groups:
    c[group] += 1  
print(c)
# Out:
# Counter({'group C': 319, 'group D': 262, 'group B': 190, 'group E': 140, 'group A': 89})

# %% [markdown]
# 3.8 Преобразование файла в список

# %% [markdown]
# Считаем оценки по математике:
# Давайте начнём с простой задачи, цель которой — выгрузить из файла оценки, полученные абитуриентами на экзамене по математике, и сделать небольшой анализ полученных результатов.
#
# Давайте рассмотрим идею алгоритма, который поможет нам решить эту задачу:
#
# 1.Создаём пустой список math, в который будем добавлять оценки.
# 2.Открываем файл и начинаем перебирать его построчно в цикле с параметром.
# 3.Полученную на каждом шаге цикла строку превращаем во временный список. Проверяем, чему равен первый элемент списка, и если это «"gender"» — пропускаем шаг, поскольку такое значение первый элемент имеет только в строке с заголовками, а эту строку обрабатывать не надо.
# 4.Если обрабатываемая строка — не заголовок, то извлекаем из неё элемент с индексом 5 (оценка по математике), отрезаем от него первый и последний символ (кавычки), переводим в тип int и добавляем к списку math.
# После завершения цикла у нас будет список из 1000 элементов, содержащий оценки всех абитуриентов по математике.

# %%
math = []

f = open('StudentsPerformance.csv')

for line in f:
    info = line.split(',')
    if info[0] == '"gender"':
        continue
    else:
        mark = int(info[5][1:-1])
        math.append(mark) 
        
math_avg = sum(math)/len(math)       # Имея данные обо всех оценках, мы можем, например, посчитать средний балл

above_avg = 0                        # и найти долю абитуриентов, показавших результат выше среднего
for mark in math:
    if mark > math_avg:
        above_avg += 1
print(above_avg / 1000)

# %% [markdown]
# Превращаем весь файл в систему вложенных списков:
#
# Каждый вложенный список будет содержать одну строку с данными.
# При этом у текстовых данных будут удалены лишние кавычки, а числовые данные будут преобразованы в тип int.
# Для удобства выбора приёмов работы с текстовыми и числовыми данными мы воспользуемся модулем re и будем проверять каждый элемент строки на предмет того, содержит ли он цифры.
#
# Вот описание общей идеи алгоритма:
# 1.Создаём паттерн, описывающий строку, состоящую только из цифр.
# 2.Создаём пустой список (exams), в который будем помещать данные.
# 3.Открываем файл.
# 4.Начинаем построчный перебор содержимого файла с помощью цикла с параметром.
# 5.Преобразуем содержимое строки в список (info), и если первым элементом списка является значение «"gender"» —пропускаем все остальные действия.
# 6.Создаём временный пустой список (new_line), в который мы будем помещать обработанные (лишённые кавычек и преобразованные в нужный формат) элементы строки.
# 7.Организуем вложенный цикл с параметром и последовательно перебираем в нём элементы строки info.
# 8.Проверяем, совпадает ли содержимое текущего элемента списка info с созданным нами паттерном (набор цифр).
# 9.Если текущий элемент строки содержит цифры (метод pattern.search(item)не возвращает значение  None) — извлекаем из обрабатываемого элемента строку, соответствующую паттерну (pattern.search(item)[0]), преобразуем е в тип int и добавляем к списку new_line; иначе добавляем к списку new_line текущее значение параметра цикла без первого и последнего символов.
# 10.Добавляем список new_line к итоговому списку exams.

# %%
import re
pattern = re.compile('\d+')  # Создаём паттерн, описывающий строку, состоящую только из цифр
exams = []                   # Создаём пустой список (exams), в который будем помещать данные
f = open('StudentsPerformance.xls')   # Открываем файл
for line in f:              # Начинаем построчный перебор содержимого файла 
    info = line.split(',')  # Преобразуем содержимое строки в список (info)
    if info[0] == '"gender"':       # Отсекаем элемент из шапки
        continue
    else:
        new_line = []       #Создаём временный пустой список, куда будем помещать лишённые кавычек и преобр-ные в int элементы
        for item in info:   # Организуем вложенный цикл и переберем в нём элементы строки info
            if pattern.search(item) != None:   #совпадает ли содержимое текущего элемента с паттерном (набор цифр)?
                new_line.append(int(pattern.search(item)[0]))  # преобразуем в тип int и добавляем к списку new_line
            else:
                new_line.append(item[1:-1])  # добавляем к списку new_line текущий элемент без кавычек
        exams.append(new_line)  # Добавляем список new_line к итоговому списку exams
print(exams)
# Out:
# [['female', 'group B', "bachelor's degree", 'standard', 'none', 72, 72, 74], ['female', 'group C', 'some college', 'standard', 'completed', 69, 90, 88], ['female', 'group B', "master's degree", 'standard', 'none', 90, 95, 93], ['male', 'group A', "associate's degree", 'free/reduced', 'none', 47, 57, 44], ['male', 'group C', 'some college', 'standard', 'none', 76, 78, 75], ['female', 'group B', "associate's degree", 'standard', 'none', 71, 83, 78], ['female', 'group B', 'some college', 'standard', 'completed', 88, 95, 92], ['male', 'group B', 'some college', 'free/reduced', 'none', 40, 43, 39], ['male', 'group D', 'high school', 'free/reduced', 'completed', 64, 64, 67], ['female', 'group B', 'high school', 'free/reduced', 'none', 38, 60, 50], ['male', 'group C', "associate's degree", 'standard', 'none', 58, 54, 52], ['male', 'group D', "associate's degree", 'standard', 'none', 40, 52, 43], ['female', 'group B', 'high school', 'standard', 'none', 65, 81, 73], ['male', 'group A', 'some 
# ...

# %% [markdown]
# Задание 1
# Вычислите средний балл абитуриентов на экзамене по чтению (reading score).

# %%
f = open('StudentsPerformance.xls')
reading=[]
summ=0
for line in f:  
    info = line.split(',') 
    if info[0] == '"gender"':      
        continue
    else:
        reading.append(int(info[6][1:-1]))
        summ=summ+int(info[6][1:-1])
print(summ/1000)
# Out:
# 69.169

# %% [markdown]
# Задание 2
# Сколько абитуриентов получили на экзамене по чтению (reading score) оценку ниже среднего?
# Введите количество абитуриентов в окно для ответа.

# %%
f = open('StudentsPerformance.xls')
bad=0
srednee=69.169
for line in f:  
    info = line.split(',') 
    if info[0] == '"gender"':      
        continue
    else:
        a=int(info[6][1:-1])
        if a < srednee:
            bad=bad+1
print(bad)
# Out:
# 487

# %% [markdown]
# Задание 3
# Какой средний балл экзамене по чтению (reading score) получили девочки?
# Ответ округлите до трёх знаков после запятой.

# %%
reading_score=0
for info in exams:
    if info[0]=='female':
        reading_score=reading_score+float(info[-2])
print(reading_score/518)
# Out:
# 72.60810810810811

# %% [markdown]
# Задание 4
# Сколько абитуриентов получили на экзамене по письму (writing score) оценку выше 90?

# %%
good=0
for info in exams:
    if info[-1]>90:
        good=good+1
print(good)
# Out:
# 68

# %% [markdown]
# Задание 5
# Сколько процентов абитуриентов, получивших на экзамене по письму (writing score) оценку более 90, хорошо пообедали перед экзаменом (lunch = standard)?
# Введите ответ в виде дробного числа без знака процента, округлив до первого знака после запятой.

# %%
standart_lunch=0
for info in exams:
    if info[-1]>90 and info[3]=='standard':
        standart_lunch=standart_lunch+1
print(standart_lunch/good*100)
# Out:
# 86.76470588235294

# %% [markdown]
# 3.9 Преобразование файла в словарь.

# %%
students = {}

f = open('StudentsPerformance.xls')

for line in f:
    info = line.split(',')
    if info[0] == '"gender"':
        continue
    else:
        ethnicity = info[1][1:-1]
        if ethnicity in students:      # проверка того, содержится ли уже в словаре ключ, совпадающий с названием
            students[ethnicity] += 1
        else:
            students[ethnicity] = 1

# %%
for group, number in students.items():
    print(group, number)
# Out:
# group B 190
# group C 319
# group A 89
# group D 262
# group E 140

# %% [markdown]
# Создаём вложенный словарь

# %%
students = {}

f = open('StudentsPerformance.xls')

for line in f:
    info = line.split(',')
    if info[0] == '"gender"':
        continue
    else:
        ethnicity = info[1][1:-1]
        parents = info[2][1:-1]
        if ethnicity in students:               # есть ли уже в словаре данные о текущей этнической группе
            if parents in students[ethnicity]:  # содержится ли во вложенном словаре ключ, соответствующий уровню образования
                students[ethnicity][parents] += 1     # увеличиваем на 1 значение, доступное по этому ключу на текущий момент
            else:
                students[ethnicity][parents] = 1      # # создаём его и помещаем в него значение, равное 1
        else:
            students[ethnicity] = {}    # создаем пустой словарь как значение, доступное в словаре students по ключу ethnicity
            students[ethnicity][parents] = 1   # создаём ключ уровня образования родителей и помещаем туда значение 1.

# %% [markdown]
# Задание 1
# Сколько мальчиков хорошо пообедали перед экзаменом (lunch = standard)?

# %%
gender_info = {}

f = open('StudentsPerformance.xls')

for line in f:
    info = line.split(',')
    if info[0] == '"gender"':
        continue
    else:
        gender = info[0][1:-1]
        meal = info[3][1:-1]
        if gender in gender_info:              
            if meal in gender_info[gender]:  
                gender_info[gender][meal] += 1     
            else:
                gender_info[gender][meal] = 1     
        else:
            gender_info[gender] = {}    
            gender_info[gender][meal] = 1
print(gender_info)
# Out:
# {'female': {'standard': 329, 'free/reduced': 189}, 'male': {'free/reduced': 166, 'standard': 316}}

# %% [markdown]
# Задание 2
# Сколько мальчиков закончили подготовительные курсы (test preparation course = completed)?

# %%
how_much=0
for info in exams:
    if info[0]=='male' and info[4]=='completed':
        how_much=how_much+1
print(how_much)
# Out:
# 174

# %% [markdown]
# Задание 3
# У скольких девочек родители имеют степень магистра (parental level of education = master's degree)?

# %%
gender_info = {}

f = open('StudentsPerformance.xls')

for line in f:
    info = line.split(',')
    if info[0] == '"gender"':
        continue
    else:
        gender = info[0][1:-1]
        parents = info[2][1:-1]
        if gender in gender_info:              
            if parents in gender_info[gender]:  
                gender_info[gender][parents] += 1     
            else:
                gender_info[gender][parents] = 1     
        else:
            gender_info[gender] = {}    
            gender_info[gender][parents] = 1
print(gender_info)
# Out:
# {'female': {"bachelor's degree": 63, 'some college': 118, "master's degree": 36, "associate's degree": 116, 'high school': 94, 'some high school': 91}, 'male': {"associate's degree": 106, 'some college': 108, 'high school': 102, "master's degree": 23, "bachelor's degree": 55, 'some high school': 88}}

# %% [markdown]
# Задание 4
# Сколько абитуриентов, относящихся к этнической группе С, закончили подготовительные курсы?

# %%
students = {}

f = open('StudentsPerformance.xls')

for line in f:
    info = line.split(',')
    if info[0] == '"gender"':
        continue
    else:
        ethnicity = info[1][1:-1]
        course = info[4][1:-1]
        if ethnicity in students:              
            if course in students[ethnicity]: 
                students[ethnicity][course] += 1    
            else:
                students[ethnicity][course] = 1     
        else:
            students[ethnicity] = {}    
            students[ethnicity][course] = 1
print(students)
# Out:
# {'group B': {'none': 122, 'completed': 68}, 'group C': {'completed': 117, 'none': 202}, 'group A': {'none': 58, 'completed': 31}, 'group D': {'completed': 82, 'none': 180}, 'group E': {'none': 80, 'completed': 60}}

# %% [markdown]
# Задание 5*
# Сколько девочек, родители которых имеют степень магистра, набрали по математике больше 90 баллов?
# Ответ введите в виде одного числа.

# %%
how_much=0
for info in exams:
    if info[0]=='female' and info[2]=="master's degree" and float(info[-3])>90:
        how_much=how_much+1
print(how_much)
# Out:
# 2

# %% [markdown]
# 3.10 Итоговый тест

# %% [markdown]
# Задание 8
# Какой средний балл, полученный мальчиками на экзамене по чтению? Ответ округлите до трёх цифр после запятой.

# %%
how_much=0
for info in exams:
    if info[0]=='male':
        how_much=how_much+float(info[-2])
print(how_much/482)
# Out:
# 65.47302904564316

# %% [markdown]
# Задание 9
# Какой средний балл на экзамене по чтению набрали ученики, набравшие максимальный балл на экзамене по математике? Ответ округлите до трёх цифр после запятой.

# %%
how_much=0
n=0
math_score=[]
for info in exams:
    math_score.append(float(info[-3]))
print(max(math_score))
for info in exams:
    if float(info[-3])==max(math_score):
        n=n+1
        how_much=how_much+float(info[-2])
print(how_much/n)
# Out:
# 100.0
# 97.85714285714286

# %% [markdown]
# Задание 10
# Какой средний балл на экзамене по письму набрали ученики, которые плохо победали перед экзаменом (lunch = free/reduced)? Ответ округлите до двух цифр после запятой.

# %%
how_much=0
n=0
for info in exams:
    if info[3]=='free/reduced':
        how_much=how_much+float(info[-1])
        n=n+1
print(how_much/n)
# Out:
# 63.02253521126761
